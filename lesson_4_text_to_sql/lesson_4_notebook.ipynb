# %% [markdown]
# # Lesson 4: Text-to-SQL RAG Agent
#
# In this lesson, we'll learn how to create an AI agent that can convert natural language queries into SQL and execute them against a database. This approach enables users to interact with databases using plain English instead of writing SQL queries.
#
# We'll build a complete text-to-SQL solution that can handle complex queries across multiple tables in an e-commerce database.

# %% [markdown]
# ## Lesson Objectives
#
# By the end of this lesson, you will be able to:
#
# 1. Set up and populate a SQLite database from CSV data
# 2. Create basic text-to-SQL conversions using LLMs
# 3. Build database schema understanding for the AI agent
# 4. Implement SQL execution with safety measures
# 5. Use function calling to create dynamic text-to-SQL agents
# 6. Handle complex multi-table queries and relationships
# 7. Create a conversational database interface with error handling

# %% [markdown]
# ## 1. Environment Setup
#
# First, let's set up our environment and generate the sample data.

# %%
# Install required packages if needed
# !pip install faker pandas sqlite3 openai python-dotenv

# %%
# Import required libraries
import sqlite3
import pandas as pd
import os
import json
from dotenv import load_dotenv, find_dotenv
from openai import AzureOpenAI
from IPython.display import display, HTML, Markdown
import subprocess
import sys

# Load environment variables
load_dotenv(find_dotenv())
# Out:
# True

# %%
# Get API keys and configuration
API_KEY = os.environ.get("AZURE_OPENAI_KEY") 
API_ENDPOINT = os.environ.get("AZURE_OPENAI_ENDPOINT")
AZURE_DEPLOYMENT = os.environ.get("AZURE_OPENAI_DEPLOYMENT_NAME")
API_VERSION = os.environ.get("AZURE_OPENAI_VERSION")
MODEL = os.environ.get("AZURE_OPENAI_MODEL")

# Check if the necessary API keys are available
if not API_KEY:
    print("⚠️ Azure OpenAI API key not found. Please set the AZURE_OPENAI_KEY environment variable.")
else:
    print("✅ Azure OpenAI configuration loaded successfully")
# Out:
# ✅ Azure OpenAI configuration loaded successfully

# %%
# Initialize Azure OpenAI client
client = AzureOpenAI(
    default_headers={"Ocp-Apim-Subscription-Key": API_KEY},
    api_key=API_KEY,
    azure_endpoint=API_ENDPOINT,
    azure_deployment=AZURE_DEPLOYMENT,
    api_version=API_VERSION, 
)

print(f"Using model: {MODEL}")
# Out:
# Using model: gpt-4o-mini

# %% [markdown]
# ## 2. Generate Sample Data
#
# Let's generate our sample e-commerce data using the create_dummy_data.py script.
#
# run the `create_dummy_data.py` file

# %% [markdown]
# ## 3. Load Data and Create SQLite Database
#
# Now let's load our CSV files and create a SQLite database.

# %%
# Load CSV files
path_dataset = '../lesson_4_text_to_sql/dataset/'
customers_df = pd.read_csv(path_dataset+'customers.csv')
products_df = pd.read_csv(path_dataset+'products.csv')
orders_df = pd.read_csv(path_dataset+'orders.csv')
order_items_df = pd.read_csv(path_dataset+'order_items.csv')
reviews_df = pd.read_csv(path_dataset+'reviews.csv')

print("Data loaded successfully!")
print(f"Customers: {len(customers_df)} rows")
print(f"Products: {len(products_df)} rows")
print(f"Orders: {len(orders_df)} rows")
print(f"Order Items: {len(order_items_df)} rows")
print(f"Reviews: {len(reviews_df)} rows")
# Out:
# Data loaded successfully!
# Customers: 1000 rows
# Products: 200 rows
# Orders: 2000 rows
# Order Items: 5111 rows
# Reviews: 1500 rows

# %%
# Create SQLite database
db_name = 'sample_database.sqlite'

# Remove existing database if it exists
if os.path.exists(db_name):
    os.remove(db_name)

# Create connection
conn = sqlite3.connect(db_name)

# Create tables from DataFrames
customers_df.to_sql('customers', conn, index=False, if_exists='replace')
products_df.to_sql('products', conn, index=False, if_exists='replace')
orders_df.to_sql('orders', conn, index=False, if_exists='replace')
order_items_df.to_sql('order_items', conn, index=False, if_exists='replace')
reviews_df.to_sql('reviews', conn, index=False, if_exists='replace')

conn.close()
print(f"SQLite database '{db_name}' created successfully!")
# Out:
# SQLite database 'sample_database.sqlite' created successfully!

# %%
min_date = orders_df['order_date'].min()
max_date = orders_df['order_date'].max()
print(f"Date range in orders: {min_date} to {max_date}")
# Out:
# Date range in orders: 2024-07-09 to 2025-07-09

# %%
# Let's examine our database schema
conn = sqlite3.connect(db_name)
cursor = conn.cursor()

# %%
# Get table names
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

print("Database Tables:")
for table in tables:
    table_name = table[0]
    print(f"\n--- {table_name.upper()} ---")
    
    # Get column info
    cursor.execute(f"PRAGMA table_info({table_name});")
    columns = cursor.fetchall()
    
    for col in columns:
        print(f"  {col[1]} ({col[2]})")
    
    # Get row count
    cursor.execute(f"SELECT COUNT(*) FROM {table_name};")
    count = cursor.fetchone()[0]
    print(f"  Rows: {count}")

conn.close()
# Out:
# Database Tables:
#
# --- CUSTOMERS ---
#   customer_id (TEXT)
#   first_name (TEXT)
#   last_name (TEXT)
#   email (TEXT)
#   phone (TEXT)
#   date_of_birth (TEXT)
#   address (TEXT)
#   city (TEXT)
#   state (TEXT)
#   country (TEXT)
#   registration_date (TEXT)
#   customer_status (TEXT)
#   total_spent (REAL)
#   Rows: 1000
#
# --- PRODUCTS ---
#   product_id (TEXT)
#   product_name (TEXT)
#   category (TEXT)
#   price (REAL)
#   cost (REAL)
#   stock_quantity (INTEGER)
#   supplier (TEXT)
#   description (TEXT)
#   created_date (TEXT)
#   is_active (INTEGER)
#   Rows: 200
#
# --- ORDERS ---
#   order_id (TEXT)
#   customer_id (TEXT)
#   order_date (TEXT)
#   status (TEXT)
#   total_amount (REAL)
#   shipping_address (TEXT)
#   payment_method (TEXT)
#   Rows: 2000
#
# --- ORDER_ITEMS ---
#   item_id (TEXT)
#   order_id (TEXT)
#   product_id (TEXT)
#   quantity (INTEGER)
#   unit_price (REAL)
#   total_price (REAL)
#   Rows: 5111
#
# --- REVIEWS ---
#   review_id (TEXT)
#   customer_id (TEXT)
#   product_id (TEXT)
#   rating (INTEGER)
#   review_text (TEXT)
#   review_date (TEXT)
#   helpful_votes (INTEGER)
#   Rows: 1500

# %% [markdown]
# ## 4. Database Helper Functions
#
# Let's create some helper functions to interact with our database safely.

# %%
def get_database_schema():
    """
    Get the complete database schema including tables, columns, and relationships
    """
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()
    
    schema_info = {}
    
    # Get all tables
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = [table[0] for table in cursor.fetchall()]
    
    for table in tables:
        # Get column information
        cursor.execute(f"PRAGMA table_info({table});")
        columns = cursor.fetchall()
        
        schema_info[table] = {
            'columns': [(col[1], col[2]) for col in columns],
            'sample_data': []
        }
        
        # Get sample data (first 3 rows)
        cursor.execute(f"SELECT * FROM {table} LIMIT 3;")
        sample_rows = cursor.fetchall()
        
        if sample_rows:
            column_names = [col[1] for col in columns]
            for row in sample_rows:
                schema_info[table]['sample_data'].append(dict(zip(column_names, row)))
    
    conn.close()
    return schema_info

def execute_sql_query(query, max_results=50):
    """
    Execute SQL query safely with result limiting
    """
    try:
        conn = sqlite3.connect(db_name)
        cursor = conn.cursor()
        
        # Add LIMIT if not already present and it's a SELECT query
        if query.strip().upper().startswith('SELECT') and 'LIMIT' not in query.upper():
            query += f' LIMIT {max_results}'
        
        cursor.execute(query)
        
        if query.strip().upper().startswith('SELECT'):
            results = cursor.fetchall()
            column_names = [description[0] for description in cursor.description]
            
            # Convert to list of dictionaries for better display
            formatted_results = []
            for row in results:
                formatted_results.append(dict(zip(column_names, row)))
            
            conn.close()
            return {
                'success': True,
                'results': formatted_results,
                'column_names': column_names,
                'row_count': len(formatted_results)
            }
        else:
            conn.commit()
            conn.close()
            return {
                'success': True,
                'message': 'Query executed successfully',
                'affected_rows': cursor.rowcount
            }
            
    except Exception as e:
        if 'conn' in locals():
            conn.close()
        return {
            'success': False,
            'error': str(e)
        }

# %%
# Test our helper functions
schema = get_database_schema()
print("Database schema loaded successfully!")
print(f"Tables: {list(schema.keys())}")
# Out:
# Database schema loaded successfully!
# Tables: ['customers', 'products', 'orders', 'order_items', 'reviews']

# %% [markdown]
# ## 5. Basic Text-to-SQL Conversion
#
# Let's start with a simple text-to-SQL conversion using the LLM directly.

# %%
def create_schema_prompt():
    """Create a detailed schema description for the LLM"""
    schema = get_database_schema()
    
    schema_description = """
DATABASE SCHEMA:
This is an e-commerce database with the following tables and relationships:

"""
    
    for table_name, table_info in schema.items():
        schema_description += f"\n{table_name.upper()} TABLE:\n"
        schema_description += "Columns:\n"
        
        for column_name, column_type in table_info['columns']:
            schema_description += f"  - {column_name} ({column_type})\n"
        
        if table_info['sample_data']:
            schema_description += "\nSample data:\n"
            for i, sample in enumerate(table_info['sample_data'][:2]):
                schema_description += f"  Row {i+1}: {sample}\n"
        
        schema_description += "\n"
    
    schema_description += """
KEY RELATIONSHIPS:
- customers.customer_id → orders.customer_id
- orders.order_id → order_items.order_id  
- products.product_id → order_items.product_id
- customers.customer_id → reviews.customer_id
- products.product_id → reviews.product_id

IMPORTANT NOTES:
- Use proper JOIN statements when querying multiple tables
- Always include LIMIT clause for large result sets
- Use aggregate functions (COUNT, SUM, AVG) for analytical queries
- Handle date filtering properly (dates are stored as text in YYYY-MM-DD format)
"""
    
    return schema_description

# %%
# Test schema prompt
schema_prompt = create_schema_prompt()
print("Schema prompt created!")
print("First 500 characters:")
print(schema_prompt[:500] + "...")
# Out:
# Schema prompt created!
# First 500 characters:
#
# DATABASE SCHEMA:
# This is an e-commerce database with the following tables and relationships:
#
#
# CUSTOMERS TABLE:
# Columns:
#   - customer_id (TEXT)
#   - first_name (TEXT)
#   - last_name (TEXT)
#   - email (TEXT)
#   - phone (TEXT)
#   - date_of_birth (TEXT)
#   - address (TEXT)
#   - city (TEXT)
#   - state (TEXT)
#   - country (TEXT)
#   - registration_date (TEXT)
#   - customer_status (TEXT)
#   - total_spent (REAL)
#
# Sample data:
#   Row 1: {'customer_id': 'bdd640fb-0667-4ad1-9c80-317fa3b1799d', 'first_name': 'Joshua', ...

# %%
def text_to_sql_basic(natural_language_query):
    """
    Convert natural language query to SQL using basic prompting
    """
    
    system_prompt = f"""You are a SQL expert. Convert natural language queries to SQL.

{create_schema_prompt()}

Rules:
1. Generate only valid SQLite SQL queries
2. Always use proper JOINs when accessing multiple tables
3. Include LIMIT 50 by default unless user specifies otherwise
4. Use appropriate WHERE clauses for filtering
5. Return only the SQL query, no explanations

Convert the following natural language query to SQL:"""

    try:
        response = client.chat.completions.create(
            model=MODEL,
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": natural_language_query}
            ],
            temperature=0.1,
            max_tokens=500
        )
        
        sql_query = response.choices[0].message.content.strip()
        
        # Clean up the response (remove markdown if present)
        if sql_query.startswith('```sql'):
            sql_query = sql_query.replace('```sql', '').replace('```', '').strip()
        elif sql_query.startswith('```'):
            sql_query = sql_query.replace('```', '').strip()
            
        return sql_query
        
    except Exception as e:
        return f"Error generating SQL: {str(e)}"

# %%
# Test basic text-to-SQL
query1 = "Show me the first 10 customers"
sql1 = text_to_sql_basic(query1)
print(f"Query: {query1}")
print(f"Generated SQL: {sql1}")
# Out:
# Query: Show me the first 10 customers
# Generated SQL: SELECT * FROM CUSTOMERS
# LIMIT 10;

# %%
# Execute the query
result1 = execute_sql_query(sql1)
if result1['success']:
    print(f"Results ({result1['row_count']} rows):")
    for i, row in enumerate(result1['results'][:5]):
        print(f"  {i+1}: {row}")
else:
    print(f"Error: {result1['error']}")
# Out:
# Results (10 rows):
#   1: {'customer_id': 'bdd640fb-0667-4ad1-9c80-317fa3b1799d', 'first_name': 'Joshua', 'last_name': 'Walker', 'email': 'rhodespatricia@example.org', 'phone': '001-260-501-3389', 'date_of_birth': '1989-08-18', 'address': '79402 Peterson Drives Apt. 511, Davisstad, PA 35172', 'city': 'Lake Stephenville', 'state': 'Missouri', 'country': 'Belgium', 'registration_date': '2024-08-16', 'customer_status': 'Premium', 'total_spent': 565.54}
#   2: {'customer_id': 'e2acf72f-9e57-4f7a-a0ee-89aed453dd32', 'first_name': 'Michelle', 'last_name': 'Ray', 'email': 'williamsjeremy@example.com', 'phone': '731-564-7525', 'date_of_birth': '1986-09-28', 'address': '283 Steven Groves, Lake Mark, WI 07832', 'city': 'Port Antonio', 'state': 'Massachusetts', 'country': 'Iran', 'registration_date': '2024-01-21', 'customer_status': 'Premium', 'total_spent': 1382.4}
#   3: {'customer_id': '9132b63e-f162-47e4-a9c3-49e03602f8ac', 'first_name': 'Nancy', 'last_name': 'Edwards', 'email': 'pfoster@example.com', 'phone': '(842)738-8496', 'date_of_birth': '1958-05-04', 'address': 'Unit 8710 Box 1226, DPO AP 08827', 'city': 'Jamesmouth', 'state': 'North Dakota', 'country': 'El Salvador', 'registration_date': '2025-06-18', 'customer_status': 'Active', 'total_spent': 706.29}
#   4: {'customer_id': 'ae270da7-02f0-4b90-b143-262fdc5c0eed', 'first_name': 'Jennifer', 'last_name': 'Maldonado', 'email': 'kayla51@example.com', 'phone': '(727)404-8281x48932', 'date_of_birth': '1978-07-03', 'address': '570 Sarah Wells, Johnbury, FM 74865', 'city': 'North Jessicaland', 'state': 'Wisconsin', 'country': 'Martinique', 'registration_date': '2025-01-19', 'customer_status': 'Active', 'total_spent': 3386.73}
#   5: {'customer_id': 'f264accc-79ac-4b1e-a8e5-6e0c20de435d', 'first_name': 'Andrea', 'last_name': 'Baker', 'email': 'ibrandt@example.net', 'phone': '001-734-265-7871x331', 'date_of_birth': '1981-08-01', 'address': '10310 Jones Freeway, Elizabethborough, ND 17843', 'city': 'Sanchezfort', 'state': 'Nebraska', 'country': 'Comoros', 'registration_date': '2023-09-16', 'customer_status': 'Premium', 'total_spent': 443.82}

# %%
# Test more complex queries
test_queries = [
    "How many orders were placed last 12 months?",
    "What are the top 5 most expensive products?",
    "Show me customers from New York who have placed orders",
    "What's the average order value?",
    "Which products have the highest ratings?"
]

for i, query in enumerate(test_queries):
    print(f"\nQuery:{i+1} {'='*50}")
    print(f"Query: {query}")
    
    sql = text_to_sql_basic(query)
    print(f"SQL: {sql}")
    
    result = execute_sql_query(sql)
    if result['success']:
        print(f"✅ Success - {result['row_count']} rows returned")
        if result['results']:
            print("Sample results:")
            for row in result['results'][:3]:
                print(f"  {row}")
    else:
        print(f"❌ Error: {result['error']}")
# Out:
# Query:1 ==================================================
# Query: How many orders were placed last 12 months?
# SQL: SELECT COUNT(*) AS total_orders
# FROM orders
# WHERE order_date >= DATE('now', '-12 months')
# LIMIT 50;
# ✅ Success - 1 rows returned
# Sample results:
#   {'total_orders': 1995}
#
# Query:2 ==================================================
# Query: What are the top 5 most expensive products?
# SQL: SELECT * FROM PRODUCTS
# ORDER BY price DESC
# LIMIT 5;
# ✅ Success - 5 rows returned
# Sample results:
#   {'product_id': 'd4bec327-edb0-4515-8835-cd464f9b7f22', 'product_name': 'Front-line next generation hierarchy', 'category': 'Beauty', 'price': 997.71, 'cost': 242.42, 'stock_quantity': 302, 'supplier': 'Reed, Rivera and White', 'description': 'Quite born play. Question few final support man center.\nArm bit road reality talk. Add country care bill prepare lead past. Care since security.', 'created_date': '2025-05-28', 'is_active': 0}
#   {'product_id': 'e8919e4e-6ac2-49e3-83ea-839ef2517333', 'product_name': 'Front-line local pricing structure', 'category': 'Beauty', 'price': 992.89, 'cost': 192.47, 'stock_quantity': 890, 'supplier': 'Cline and Sons', 'description': 'These over reach family want. Rather be culture year. Form keep particularly air American control. Hold system sense magazine voice arm.\nGive tell window kind available race. Who apply between human.', 'created_date': '2024-10-13', 'is_active': 0}
#   {'product_id': '82a4f8be-7498-4fe2-9c6d-3a4ccbbb6d7b', 'product_name': 'Intuitive foreground capability', 'category': 'Clothing', 'price': 986.21, 'cost': 237.09, 'stock_quantity': 293, 'supplier': 'Warren Inc', 'description': 'Leg wonder term summer second deal so question. Campaign fight coach likely happen. Consider top at wait health. Half little miss defense chance author.\nProve senior six hour the front fire.', 'created_date': '2024-11-11', 'is_active': 0}
#
# Query:3 ==================================================
# Query: Show me customers from New York who have placed orders
# SQL: SELECT DISTINCT c.*
# FROM CUSTOMERS c
# JOIN ORDERS o ON c.customer_id = o.customer_id
# WHERE c.state = 'New York'
# LIMIT 50;
# ✅ Success - 18 rows returned
# Sample results:
#   {'customer_id': 'c2b01cfd-d045-4d1c-a684-09e3f1f8343e', 'first_name': 'Andrea', 'last_name': 'Gibson', 'email': 'johnny16@example.net', 'phone': '9879603859', 'date_of_birth': '1992-05-26', 'address': '7710 Jennifer Inlet, New Rickybury, MP 15372', 'city': 'Valentineberg', 'state': 'New York', 'country': 'Venezuela', 'registration_date': '2024-12-14', 'customer_status': 'Premium', 'total_spent': 632.88}
#   {'customer_id': '6a5d932b-45ff-4c83-b495-db4e82456fb4', 'first_name': 'Mary', 'last_name': 'Baird', 'email': 'stephenthomas@example.org', 'phone': '+1-982-414-6584x044', 'date_of_birth': '1972-08-27', 'address': '867 Kane Square Apt. 963, Williamsfort, VT 50469', 'city': 'Mcneilberg', 'state': 'New York', 'country': 'Argentina', 'registration_date': '2023-10-10', 'customer_status': 'Inactive', 'total_spent': 403.21}
#   {'customer_id': 'df482e7c-a8cf-4f62-90d9-170cf2dec75c', 'first_name': 'Tammy', 'last_name': 'Fitzgerald', 'email': 'ccrosby@example.org', 'phone': '001-273-214-5303x85677', 'date_of_birth': '2006-04-19', 'address': '498 Nicholas Lane Suite 918, Nicholasbury, NC 53695', 'city': 'Lisastad', 'state': 'New York', 'country': 'Somalia', 'registration_date': '2024-06-26', 'customer_status': 'Inactive', 'total_spent': 1079.04}
#
# Query:4 ==================================================
# Query: What's the average order value?
# SQL: SELECT AVG(total_amount) AS average_order_value
# FROM orders
# LIMIT 50;
# ✅ Success - 1 rows returned
# Sample results:
#   {'average_order_value': 3741.3346800000004}
#
# Query:5 ==================================================
# Query: Which products have the highest ratings?
# SQL: SELECT p.product_id, p.product_name, AVG(r.rating) AS average_rating
# FROM products p
# JOIN reviews r ON p.product_id = r.product_id
# GROUP BY p.product_id, p.product_name
# ORDER BY average_rating DESC
# LIMIT 50;
# ✅ Success - 50 rows returned
# Sample results:
#   {'product_id': 'd607b0e5-5ab9-4a05-9e2e-8da6766ab420', 'product_name': 'Reverse-engineered foreground info-mediaries', 'average_rating': 4.666666666666667}
#   {'product_id': '01aa3995-1a80-4743-af29-eb7f7e5a047b', 'product_name': 'Organized real-time functionalities', 'average_rating': 4.5}
#   {'product_id': '218c756c-c99b-4a14-af5f-611fbf05cc37', 'product_name': 'Fully-configurable upward-trending instruction set', 'average_rating': 4.5}

# %% [markdown]
# ## 6. Function Calling for Text-to-SQL
#
# Now let's create a more sophisticated agent using function calling. This allows the AI to execute queries and provide natural language responses.

# %%
# Define SQL execution function for function calling
sql_execution_function = {
    "name": "execute_sql_query",
    "description": "Execute a SQL query against the e-commerce database and return results",
    "parameters": {
        "type": "object",
        "properties": {
            "sql_query": {
                "type": "string",
                "description": "The SQL query to execute. Must be valid SQLite syntax."
            },
            "explanation": {
                "type": "string", 
                "description": "Brief explanation of what the query does"
            }
        },
        "required": ["sql_query", "explanation"]
    }
}

# Define database schema function
schema_function = {
    "name": "get_database_schema",
    "description": "Get information about database tables, columns, and sample data",
    "parameters": {
        "type": "object",
        "properties": {},
        "required": []
    }
}

available_functions = [sql_execution_function, schema_function]

# %%
def sql_agent_with_functions(user_query, conversation_history=None):
    """
    Advanced SQL agent using function calling
    """
    if conversation_history is None:
        conversation_history = []
    
    system_prompt = f"""You are an intelligent database assistant that helps users query an e-commerce database using natural language.

{create_schema_prompt()}

Your capabilities:
1. Convert natural language to SQL queries
2. Execute SQL queries safely 
3. Interpret and explain results in natural language
4. Handle follow-up questions and maintain context

Guidelines:
- Always use proper JOINs for multi-table queries
- Include appropriate WHERE clauses for filtering
- Use LIMIT to prevent overwhelming results
- Provide clear, helpful explanations of results
- Ask for clarification if the query is ambiguous
- If a query fails, suggest corrections

Be conversational and helpful in your responses."""

    messages = [{"role": "system", "content": system_prompt}]
    
    # Add conversation history
    if conversation_history:
        messages.extend(conversation_history)
    
    # Add current user query
    messages.append({"role": "user", "content": user_query})
    
    try:
        # First LLM call to decide what to do
        response = client.chat.completions.create(
            model=MODEL,
            messages=messages,
            tools=[
                {"type": "function", "function": sql_execution_function},
                {"type": "function", "function": schema_function}
            ],
            tool_choice="auto",
            temperature=0.1
        )
        
        response_message = response.choices[0].message
        
        # Check if the model wants to call a function
        if response_message.tool_calls:
            messages.append(response_message)
            
            # Execute each function call
            for tool_call in response_message.tool_calls:
                function_name = tool_call.function.name
                function_args = json.loads(tool_call.function.arguments)
                
                print(f"🔧 Executing: {function_name}")
                if 'sql_query' in function_args:
                    print(f"📝 SQL: {function_args['sql_query']}")
                    print(f"💭 Explanation: {function_args['explanation']}")
                
                # Call the appropriate function
                if function_name == "execute_sql_query":
                    function_result = execute_sql_query(function_args['sql_query'])
                elif function_name == "get_database_schema":
                    function_result = get_database_schema()
                else:
                    function_result = {"error": "Unknown function"}
                
                # Add function result to messages
                messages.append({
                    "tool_call_id": tool_call.id,
                    "role": "tool",
                    "name": function_name,
                    "content": json.dumps(function_result)
                })
            
            # Get final response from the model
            final_response = client.chat.completions.create(
                model=MODEL,
                messages=messages,
                temperature=0.1
            )
            
            return {
                'response': final_response.choices[0].message.content,
                'messages': messages,
                'function_calls': len(response_message.tool_calls) if response_message.tool_calls else 0
            }
        
        else:
            # No function call needed, return direct response
            return {
                'response': response_message.content,
                'messages': messages,
                'function_calls': 0
            }
            
    except Exception as e:
        return {
            'response': f"I encountered an error: {str(e)}",
            'messages': messages,
            'function_calls': 0
        }

# %%
# Test the SQL agent
test_query = "Show me the top 5 customers by total spending"
result = sql_agent_with_functions(test_query)

print("🤖 Agent Response:")
print(result['response'])
print(f"\n📊 Function calls made: {result['function_calls']}")
# Out:
# 🔧 Executing: execute_sql_query
# 📝 SQL: SELECT first_name, last_name, total_spent FROM CUSTOMERS ORDER BY total_spent DESC LIMIT 5;
# 💭 Explanation: This query retrieves the top 5 customers based on their total spending, ordered from highest to lowest.
# 🤖 Agent Response:
# Here are the top 5 customers by total spending:
#
# 1. **Theresa Stone** - $4,997.98
# 2. **Ronald Zhang** - $4,997.87
# 3. **Sean Coleman** - $4,996.87
# 4. **Jennifer Smith** - $4,996.42
# 5. **Jennifer Robinson** - $4,994.52
#
# If you need more information or have any other questions, feel free to ask!
#
# 📊 Function calls made: 1

# %%
# Test more complex scenarios
complex_queries = [
    "What's the most popular product category?",
    "Show me orders from the last 30 days",
    "Which customers have never left a review?",
    "What's the average rating for Electronics products?",
    "Find customers who have spent more than $1000 and show their details"
]

for i, query in enumerate(complex_queries):
    print(f"\nQuery:{i+1} {'='*60}")
    print(f"🔍 Query: {query}")
    print("-" * 60)
    
    result = sql_agent_with_functions(query)
    print("🤖 Response:")
    print(result['response'])
    print(f"📊 Function calls: {result['function_calls']}")
# Out:
# Query:1 ============================================================
# 🔍 Query: What's the most popular product category?
# ------------------------------------------------------------
# 🔧 Executing: execute_sql_query
# 📝 SQL: SELECT p.category, COUNT(oi.product_id) AS order_count
# FROM order_items oi
# JOIN products p ON oi.product_id = p.product_id
# GROUP BY p.category
# ORDER BY order_count DESC
# LIMIT 1;
# 💭 Explanation: This query counts the number of orders for each product category by joining the order_items and products tables, grouping by category, and ordering the results to find the most popular category.
# 🤖 Response:
# The most popular product category is **Food**, with a total of **809** orders. If you have any more questions or need further information, feel free to ask!
# 📊 Function calls: 1
#
# Query:2 ============================================================
# 🔍 Query: Show me orders from the last 30 days
# ------------------------------------------------------------
# 🔧 Executing: execute_sql_query
# 📝 SQL: SELECT * FROM orders WHERE order_date >= date('now', '-30 days')
# 💭 Explanation: This query retrieves all orders placed in the last 30 days by filtering the order_date column.
# 🤖 Response:
# Here are the orders placed in the last 30 days:
#
# 1. **Order ID:** f4d9fe49-52ee-4491-a637-8527d1efb6f6
#    - **Customer ID:** c102da6e-7a9f-443b-adc3-d6a27647547c
#    - **Order Date:** 2025-07-02
#    - **Status:** Cancelled
#    - **Total Amount:** $5162.15
#    - **Shipping Address:** 70278 Wells Hills, Stephenshire, WY 25592
#    - **Payment Method:** Credit Card
#
# 2. **Order ID:** c4f4ab49-3201-4d90-aa5f-9dd6702b6c70
#    - **Customer ID:** 6a5d932b-45ff-4c83-b495-db4e82456fb4
#    - **Order Date:** 2025-06-18
#    - **Status:** Pending
#    - **Total Amount:** $4922.72
#    - **Shipping Address:** 57337 Huang Path Suite 091, West Charles, NM 66932
#    - **Payment Method:** Credit Card
#
# 3. **Order ID:** 20d1ce57-048e-4f6c-a5dc-4e9eb1f73955
#    - **Customer ID:** 0b022156-82a0-46e9-8b44-aa7165454a72
#    - **Order Date:** 2025-07-09
#    - **Status:** Cancelled
#    - **Total Amount:** $3633.53
#    - **Shipping Address:** 5371 Brewer Grove Suite 196, Stephensmouth, NM 72649
#    - **Payment Method:** Credit Card
#
# 4. **Order ID:** a6c5b579-f4f1-4e1d-a368-cb5f464fc32c
#    - **Customer ID:** b9ee2247-09fc-4dac-979e-f85745de0e0b
#    - **Order Date:** 2025-07-09
#    - **Status:** Cancelled
#    - **Total Amount:** $2521.35
#    - **Shipping Address:** 746 Glenn Shoals Apt. 900, West Christopher, MA 15322
#    - **Payment Method:** Bank Transfer
#
# 5. **Order ID:** caf0980f-c584-4e6c-b780-66cc95102d46
#    - **Customer ID:** af2b99b4-d9ac-4158-8d34-85c5c5c14eb4
#    - **Order Date:** 2025-07-05
#    - **Status:** Pending
#    - **Total Amount:** $3689.65
#    - **Shipping Address:** 42314 Hammond Expressway Apt. 258, Williamsberg, SD 01142
#    - **Payment Method:** Credit Card
#
# ... and many more.
#
# This is a sample of the first five orders. If you would like to see more details or specific orders, please let me know!
# 📊 Function calls: 1
#
# Query:3 ============================================================
# 🔍 Query: Which customers have never left a review?
# ------------------------------------------------------------
# 🔧 Executing: execute_sql_query
# 📝 SQL: SELECT c.customer_id, c.first_name, c.last_name, c.email
# FROM CUSTOMERS c
# LEFT JOIN REVIEWS r ON c.customer_id = r.customer_id
# WHERE r.review_id IS NULL
# LIMIT 10;
# 💭 Explanation: This query selects customers who have never left a review by performing a LEFT JOIN between the CUSTOMERS and REVIEWS tables and filtering for customers with no corresponding reviews.
# 🤖 Response:
# Here are some customers who have never left a review:
#
# 1. **Michelle Ray** - Email: williamsjeremy@example.com
# 2. **Nancy Edwards** - Email: pfoster@example.com
# 3. **Robert Shields** - Email: nuneztracey@example.org
# 4. **James Sellers** - Email: kevin33@example.org
# 5. **Amanda Ball** - Email: michaeljones@example.net
# 6. **Joshua Carlson** - Email: angela83@example.org
# 7. **Craig Kirk** - Email: foxstephen@example.net
# 8. **Maria Scott** - Email: scoffey@example.net
# 9. **Paul Watson** - Email: umatthews@example.org
# 10. **William Ford** - Email: colelisa@example.net
#
# If you need more information or further assistance, feel free to ask!
# 📊 Function calls: 1
#
# Query:4 ============================================================
# 🔍 Query: What's the average rating for Electronics products?
# ------------------------------------------------------------
# 🔧 Executing: execute_sql_query
# 📝 SQL: SELECT AVG(rating) AS average_rating FROM reviews r JOIN products p ON r.product_id = p.product_id WHERE p.category = 'Electronics';
# 💭 Explanation: This query calculates the average rating for products in the Electronics category by joining the reviews and products tables.
# 🤖 Response:
# It seems there was an issue executing the query. Let me break it down and try again.
#
# I'll calculate the average rating for Electronics products by joining the `reviews` and `products` tables. Here's the SQL query I'll use:
#
# ```sql
# SELECT AVG(rating) AS average_rating
# FROM reviews r
# JOIN products p ON r.product_id = p.product_id
# WHERE p.category = 'Electronics';
# ```
#
# Now, let me execute this query.
# 📊 Function calls: 1
#
# Query:5 ============================================================
# 🔍 Query: Find customers who have spent more than $1000 and show their details
# ------------------------------------------------------------
# 🔧 Executing: execute_sql_query
# 📝 SQL: SELECT * FROM CUSTOMERS WHERE total_spent > 1000
# 💭 Explanation: This query retrieves all customer details from the CUSTOMERS table where the total amount spent by the customer is greater than $1000.
# 🤖 Response:
# Here are the details of customers who have spent more than $1000:
#
# 1. **Michelle Ray**
#    - Email: williamsjeremy@example.com
#    - Phone: 731-564-7525
#    - Date of Birth: 1986-09-28
#    - Address: 283 Steven Groves, Lake Mark, WI 07832
#    - City: Port Antonio
#    - State: Massachusetts
#    - Country: Iran
#    - Registration Date: 2024-01-21
#    - Customer Status: Premium
#    - Total Spent: $1382.40
#
# 2. **Jennifer Maldonado**
#    - Email: kayla51@example.com
#    - Phone: (727)404-8281x48932
#    - Date of Birth: 1978-07-03
#    - Address: 570 Sarah Wells, Johnbury, FM 74865
#    - City: North Jessicaland
#    - State: Wisconsin
#    - Country: Martinique
#    - Registration Date: 2025-01-19
#    - Customer Status: Active
#    - Total Spent: $3386.73
#
# 3. **Spencer Henderson**
#    - Email: smoore@example.org
#    - Phone: 4982050097
#    - Date of Birth: 2005-01-18
#    - Address: 91361 Beth Canyon, South Dianeshire, NC 41968
#    - City: Jamesmouth
#    - State: Kansas
#    - Country: Estonia
#    - Registration Date: 2024-04-24
#    - Customer Status: Active
#    - Total Spent: $1101.00
#
# 4. **Leslie Walton**
#    - Email: smithchristine@example.net
#    - Phone: 518-738-4251
#    - Date of Birth: 1962-06-23
#    - Address: 808 Huynh Cove Apt. 411, West Juan, IL 94559
#    - City: Jamesview
#    - State: North Carolina
#    - Country: Liechtenstein
#    - Registration Date: 2024-01-09
#    - Customer Status: Premium
#    - Total Spent: $3014.07
#
# 5. **Cynthia Calderon**
#    - Email: smithkellie@example.net
#    - Phone: 727-486-8011x280
#    - Date of Birth: 1971-08-07
#    - Address: 53315 Dickson Summit Apt. 322, Johnsonmouth, WY 54465
#    - City: West Erik
#    - State: Vermont
#    - Country: Botswana
#    - Registration Date: 2024-04-14
#    - Customer Status: Premium
#    - Total Spent: $1002.20
#
# 6. **James Sellers**
#    - Email: kevin33@example.org
#    - Phone: +1-636-454-1458x68501
#    - Date of Birth: 1981-02-05
#    - Address: Unit 0196 Box 5569, DPO AP 15658
#    - City: Lamborough
#    - State: Kentucky
#    - Country: Aruba
#    - Registration Date: 2024-12-09
#    - Customer Status: Premium
#    - Total Spent: $3509.61
#
# 7. **Amanda Ball**
#    - Email: michaeljones@example.net
#    - Phone: 895-814-8465x64823
#    - Date of Birth: 1987-03-12
#    - Address: PSC 9946, Box 8044, APO AE 56847
#    - City: Stevenmouth
#    - State: Utah
#    - Country: Croatia
#    - Registration Date: 2024-07-17
#    - Customer Status: Inactive
#    - Total Spent: $1110.00
#
# 8. **Jill Hopkins**
#    - Email: zachary95@example.org
#    - Phone: 001-534-833-2003x79176
#    - Date of Birth: 1975-09-01
#    - Address: 63287 Angela Vista, South Dennismouth, TN 70117
#    - City: Stephaniemouth
#    - State: South Carolina
#    - Country: Suriname
#    - Registration Date: 2024-12-16
#    - Customer Status: Premium
#    - Total Spent: $1398.17
#
# 9. **Amy Merritt**
#    - Email: wcole@example.org
#    - Phone: +1-348-473-4714x3455
#    - Date of Birth: 1954-01-09
#    - Address: 316 Rivera Mountain, Brownchester, MS 77057
#    - City: Port Nicoleshire
#    - State: Missouri
#    - Country: Lesotho
#    - Registration Date: 2023-07-14
#    - Customer Status: Active
#    - Total Spent: $3796.45
#
# 10. **Melissa Ashley**
#     - Email: vmedina@example.net
#     - Phone: +1-937-434-6706x562
#     - Date of Birth: 2006-04-22
#     - Address: 901 Taylor Mountain Apt. 046, Jasonmouth, MA 50193
#     - City: Karenchester
#     - State: Kentucky
#     - Country: Syrian Arab Republic
#     - Registration Date: 2023-09-07
#     - Customer Status: Active
#     - Total Spent: $3493.72
#
# This is just a selection of customers who have spent over $1000. If you need more details or specific information, feel free to ask!
# 📊 Function calls: 1

# %% [markdown]
# ## 7. Conversational SQL Interface
#
# Let's create a conversational interface that maintains context across multiple queries.

# %%
class ConversationalSQLAgent:
    def __init__(self):
        self.conversation_history = []
        self.session_context = {}
    
    def query(self, user_input):
        """Process a user query and maintain conversation context"""
        
        # Add user message to history
        self.conversation_history.append({"role": "user", "content": user_input})
        
        # Get response from SQL agent
        result = sql_agent_with_functions(user_input, self.conversation_history[:-1])
        
        # Add assistant response to history
        self.conversation_history.append({"role": "assistant", "content": result['response']})
        
        # Keep history manageable (last 10 messages)
        if len(self.conversation_history) > 10:
            self.conversation_history = self.conversation_history[-10:]
        
        return result
    
    def clear_history(self):
        """Clear conversation history"""
        self.conversation_history = []
        self.session_context = {}
    
    def get_history_summary(self):
        """Get a summary of the conversation"""
        return f"Conversation length: {len(self.conversation_history)} messages"

# Create conversational agent
agent = ConversationalSQLAgent()

print("🎯 Conversational SQL Agent Started!")
print("=" * 50)
# Out:
# 🎯 Conversational SQL Agent Started!
# ==================================================

# %%
# Simulate a conversation
conversation_queries = [
    "How many customers do we have?",
    "What about active customers only?", 
    "Show me their average spending",
    "Which of these customers are from California?",
    "What products did they buy most often?"
]

for i, query in enumerate(conversation_queries, 1):
    print(f"\n🔄 Turn {i}: {query}")
    print("-" * 40)
    
    result = agent.query(query)
    print("🤖 Agent:")
    print(result['response'])
    
    if i < len(conversation_queries):
        print("\n⏳ (continuing conversation...)")
        
print(f"\n📈 {agent.get_history_summary()}")
# Out:
# 🔄 Turn 1: How many customers do we have?
# ----------------------------------------
# 🔧 Executing: execute_sql_query
# 📝 SQL: SELECT COUNT(*) AS total_customers FROM CUSTOMERS;
# 💭 Explanation: This query counts the total number of customers in the CUSTOMERS table.
# 🤖 Agent:
# It seems there was an issue executing the query. Let me try again to count the total number of customers in the database.
#
# I'll run a simple count query now.
#
# ⏳ (continuing conversation...)
#
# 🔄 Turn 2: What about active customers only?
# ----------------------------------------
# 🔧 Executing: execute_sql_query
# 📝 SQL: SELECT COUNT(*) AS active_customer_count FROM CUSTOMERS WHERE customer_status = 'Active'
# 💭 Explanation: This query counts the total number of customers who have an 'Active' status.
# 🤖 Agent:
# There are 319 active customers in the database. If you need more details or have any other questions, feel free to ask!
#
# ⏳ (continuing conversation...)
#
# 🔄 Turn 3: Show me their average spending
# ----------------------------------------
# 🔧 Executing: execute_sql_query
# 📝 SQL: SELECT AVG(total_spent) AS average_spending FROM CUSTOMERS WHERE customer_status = 'Active';
# 💭 Explanation: This query calculates the average spending of active customers by averaging the total_spent column for customers with an active status.
# 🤖 Agent:
# It seems there was an issue executing the query for the average spending of active customers. Let me construct the query again and run it.
#
# I'll calculate the average spending for active customers now.
#
# ⏳ (continuing conversation...)
#
# 🔄 Turn 4: Which of these customers are from California?
# ----------------------------------------
# 🔧 Executing: execute_sql_query
# 📝 SQL: SELECT * FROM CUSTOMERS WHERE state = 'California' AND customer_status = 'Active';
# 💭 Explanation: This query retrieves all active customers from California.
# 🤖 Agent:
# It seems there was an issue executing the query. Let me construct the SQL query to find active customers from California and run it again.
#
# I'll check for active customers in California now.
#
# ⏳ (continuing conversation...)
#
# 🔄 Turn 5: What products did they buy most often?
# ----------------------------------------
# 🔧 Executing: execute_sql_query
# 📝 SQL: SELECT p.product_name, COUNT(oi.product_id) AS purchase_count
# FROM customers c
# JOIN orders o ON c.customer_id = o.customer_id
# JOIN order_items oi ON o.order_id = oi.order_id
# JOIN products p ON oi.product_id = p.product_id
# WHERE c.state = 'California' AND c.customer_status = 'Active'
# GROUP BY p.product_name
# ORDER BY purchase_count DESC
# LIMIT 10;
# 💭 Explanation: This query retrieves the top 10 products purchased most often by active customers from California, counting the number of times each product was bought.
# 🤖 Agent:
# Here are the products that active customers from California purchased most often:
#
# 1. **Secured multi-state emulation** - 2 purchases
# 2. **Monitored bandwidth-monitored middleware** - 2 purchases
# 3. **Versatile modular matrix** - 1 purchase
# 4. **Total secondary contingency** - 1 purchase
# 5. **Switchable executive application** - 1 purchase
# 6. **Streamlined disintermediate instruction set** - 1 purchase
# 7. **Sharable system-worthy Local Area Network** - 1 purchase
# 8. **Seamless upward-trending success** - 1 purchase
# 9. **Seamless multimedia concept** - 1 purchase
# 10. **Re-contextualized multi-tasking attitude** - 1 purchase
#
# If you need more information or have any other questions, feel free to ask!
#
# 📈 Conversation length: 10 messages

# %%
# Test error handling and recovery
print("\n🧪 Testing Error Handling")
print("=" * 50)

error_test_queries = [
    "Show me data from table that doesn't exist",
    "What's the invalid_column in products?",
    "SELECT * FROM nowhere;",
]

for query in error_test_queries:
    print(f"\n❌ Error Test: {query}")
    result = agent.query(query)
    print("🤖 Agent Response:")
    print(result['response'])
# Out:
# 🧪 Testing Error Handling
# ==================================================
#
# ❌ Error Test: Show me data from table that doesn't exist
# 🤖 Agent Response:
# It seems there was an issue with the query because the table you requested does not exist in the database.
#
# If you have a specific table or data you would like to query, please let me know, and I'll be happy to assist you!
#
# ❌ Error Test: What's the invalid_column in products?
# 🤖 Agent Response:
# It seems there was an issue executing the query for the invalid column in the products table. Let me clarify that there is no column named "invalid_column" in the products table.
#
# If you meant to ask about a specific column or if you have another question regarding the products table, please let me know!
#
# ❌ Error Test: SELECT * FROM nowhere;
# 🤖 Agent Response:
# The query `SELECT * FROM nowhere;` is attempting to select data from a table named "nowhere," which does not exist in the database. This will result in an error because the specified table cannot be found.
#
# If you have a specific table in mind or if you would like to query data from an existing table, please let me know, and I'll be happy to assist you!

# %% [markdown]
# ## 8. Advanced Features and Best Practices
#
# Let's implement some advanced features for production-ready text-to-SQL systems.

# %%
def validate_sql_query(sql_query):
    """
    Validate SQL query for safety and best practices
    """
    sql_upper = sql_query.upper()
    
    # Check for dangerous operations
    dangerous_keywords = ['DROP', 'DELETE', 'UPDATE', 'INSERT', 'ALTER', 'CREATE', 'TRUNCATE']
    
    issues = []
    
    for keyword in dangerous_keywords:
        if keyword in sql_upper:
            issues.append(f"Contains potentially dangerous keyword: {keyword}")
    
    # Check for SELECT statements only
    if not sql_upper.strip().startswith('SELECT'):
        issues.append("Only SELECT statements are allowed")
    
    # Check for LIMIT clause
    if 'LIMIT' not in sql_upper and 'COUNT(' not in sql_upper:
        issues.append("Query should include LIMIT clause to prevent large result sets")
    
    return {
        'is_valid': len(issues) == 0,
        'issues': issues
    }

def enhanced_text_to_sql(natural_language_query):
    """
    Enhanced text-to-SQL with validation and safety measures
    """
    
    # Generate SQL
    sql_query = text_to_sql_basic(natural_language_query)
    
    # Validate SQL
    validation = validate_sql_query(sql_query)
    
    if not validation['is_valid']:
        return {
            'sql': sql_query,
            'valid': False,
            'issues': validation['issues'],
            'results': None
        }
    
    # Execute if valid
    results = execute_sql_query(sql_query)
    
    return {
        'sql': sql_query,
        'valid': True,
        'issues': [],
        'results': results
    }

# %%
# Test enhanced validation
test_queries = [
    "Show me all customers",
    "Delete all customers",  # Should be rejected
    "SELECT * FROM customers",  # Should warn about LIMIT
    "UPDATE products SET price = 0"  # Should be rejected
]

for query in test_queries:
    print(f"\n🔍 Testing: {query}")
    result = enhanced_text_to_sql(query)
    
    if result['valid']:
        print("✅ Query is valid")
        print(f"📝 SQL: {result['sql']}")
    else:
        print("❌ Query validation failed")
        print(f"🚨 Issues: {', '.join(result['issues'])}")
# Out:
# 🔍 Testing: Show me all customers
# ✅ Query is valid
# 📝 SQL: SELECT * FROM CUSTOMERS LIMIT 50;
#
# 🔍 Testing: Delete all customers
# ❌ Query validation failed
# 🚨 Issues: Contains potentially dangerous keyword: DELETE, Only SELECT statements are allowed, Query should include LIMIT clause to prevent large result sets
#
# 🔍 Testing: SELECT * FROM customers
# ✅ Query is valid
# 📝 SQL: SELECT * FROM customers LIMIT 50;
#
# 🔍 Testing: UPDATE products SET price = 0
# ❌ Query validation failed
# 🚨 Issues: Contains potentially dangerous keyword: UPDATE, Only SELECT statements are allowed, Query should include LIMIT clause to prevent large result sets

# %%
def create_query_suggestions():
    """
    Provide example queries users can try
    """
    suggestions = [
        {
            "category": "Basic Queries",
            "queries": [
                "Show me all customers",
                "What products do we have?",
                "How many orders were placed today?",
                "Show me customer details for John Smith"
            ]
        },
        {
            "category": "Analytics",
            "queries": [
                "What's our total revenue?",
                "Which products are bestsellers?",
                "What's the average order value?",
                "Show me sales by month",
                "Which customers spend the most?"
            ]
        },
        {
            "category": "Complex Queries", 
            "queries": [
                "Show customers who have never placed an order",
                "What products have the highest ratings?",
                "Find customers from California who bought Electronics",
                "Show me orders with more than 3 items",
                "Which products are out of stock?"
            ]
        }
    ]
    
    return suggestions

# Display query suggestions
suggestions = create_query_suggestions()

print("💡 Query Suggestions")
print("=" * 50)

for category in suggestions:
    print(f"\n📂 {category['category']}:")
    for i, query in enumerate(category['queries'], 1):
        print(f"  {i}. {query}")
# Out:
# 💡 Query Suggestions
# ==================================================
#
# 📂 Basic Queries:
#   1. Show me all customers
#   2. What products do we have?
#   3. How many orders were placed today?
#   4. Show me customer details for John Smith
#
# 📂 Analytics:
#   1. What's our total revenue?
#   2. Which products are bestsellers?
#   3. What's the average order value?
#   4. Show me sales by month
#   5. Which customers spend the most?
#
# 📂 Complex Queries:
#   1. Show customers who have never placed an order
#   2. What products have the highest ratings?
#   3. Find customers from California who bought Electronics
#   4. Show me orders with more than 3 items
#   5. Which products are out of stock?

# %% [markdown]
# ## 9. Interactive Demo
#
# Try asking questions about the e-commerce database! The agent can handle complex queries and maintain conversation context.

# %%
# Interactive demo function
def demo_agent(user_query):
    """
    Demo function for testing queries
    """
    print(f"🔍 User Query: {user_query}")
    print("-" * 50)
    
    result = agent.query(user_query)
    
    print("🤖 Agent Response:")
    print(result['response'])
    
    if result['function_calls'] > 0:
        print(f"\n📊 Made {result['function_calls']} function call(s)")
    
    return result

# %%
# Example usage - try different queries!
demo_queries = [
    "What's the total number of products in each category?",
    "Show me the most recent orders",
    "Which customer has the highest total spending?"
]

for query in demo_queries:
    print("\n" + "="*60)
    demo_agent(query)
# Out:
# ============================================================
# 🔍 User Query: What's the total number of products in each category?
# --------------------------------------------------
# 🔧 Executing: execute_sql_query
# 📝 SQL: SELECT category, COUNT(*) AS total_products FROM PRODUCTS GROUP BY category;
# 💭 Explanation: This query counts the total number of products in each category by grouping the results based on the category.
# 🤖 Agent Response:
# It seems there was an issue executing the query. Let me provide you with the correct SQL query to get the total number of products in each category:
#
# ```sql
# SELECT category, COUNT(*) AS total_products
# FROM PRODUCTS
# GROUP BY category;
# ```
#
# This query counts the total number of products in each category by grouping the results based on the category.
#
# If you'd like, I can help you interpret the results once you run this query in your database. If you have any other questions or need further assistance, just let me know!
#
# 📊 Made 1 function call(s)
#
# ============================================================
# 🔍 User Query: Show me the most recent orders
# --------------------------------------------------
# 🔧 Executing: execute_sql_query
# 📝 SQL: SELECT * FROM ORDERS ORDER BY order_date DESC LIMIT 10;
# 💭 Explanation: This query retrieves the most recent 10 orders from the ORDERS table, sorted by order_date in descending order.
# 🤖 Agent Response:
# Here are the most recent orders from the database:
#
# | Order ID                                 | Customer ID                             | Order Date   | Status    | Total Amount | Shipping Address                                      | Payment Method |
# |------------------------------------------|-----------------------------------------|--------------|-----------|--------------|-------------------------------------------------------|-----------------|
# | eb17006c-9499-4d5d-ab21-36e4c92c2138    | 191b7b9c-ee03-4ebc-a27e-ade80d039219  | 2025-07-08   | Shipped   | 1818.75      | 5371 Brewer Grove Suite 196, Stephensmouth, NM 72649 | PayPal          |
# | ff0e8b54-16a7-41d9-9648-51d9ddbaf77f    | b0ad882f-1197-4aa1-852b-80be52939a9a  | 2025-07-08   | Delivered | 757.13       | 746 Glenn Shoals Apt. 900, West Christopher, MA 15322| Credit Card     |
# | bb01e1ba-52c6-4f5f-a815-85d890a988ca    | fdcad2fd-7d81-46b1-bffb-eba6665563c3  | 2025-07-08   | Shipped   | 5091.55      | 2772 Robert Station, Jenkinsview, NH 92029           | Credit Card     |
# | b311740a-6980-4139-933e-85b022483e07    | 34d0d4d2-861c-4c44-8e12-1d0dcca3867a  | 2025-07-08   | Cancelled | 2995.06      | 730 Mark Fork Apt. 019, West David, PR 69557        | PayPal          |
# | 71eef50d-c902-4529-8599-6416811a0584    | 24ddb37c-cd5f-4328-93b1-1ee8737eefb6  | 2025-07-08   | Cancelled | 5347.68      | USS Cochran, FPO AE 91617                             | Credit Card     |
# | 65b616e2-384f-4419-91bc-3c4e6e44daa6    | d01e7afb-2c2c-4ee5-9935-0e527cdd893f  | 2025-07-08   | Pending   | 7889.89      | 76018 Jacob Knolls Suite 981, Carlsonbury, SD 48489 | PayPal          |
# | 35b880d7-ac28-48c3-9ccc-bf9d4d0a36bc    | 28507771-956d-4b7e-8579-751f9848bc73  | 2025-07-07   | Pending   | 1866.72      | Unit 0597 Box 4689, DPO AP 30342                     | PayPal          |
# | 82701ea7-066a-4938-90dc-db407b10d509    | 94f7ea7b-a312-48f4-8c96-ddc1c120c039  | 2025-07-07   | Shipped   | 857.10       | 8679 David Well Apt. 278, Gonzalezport, ND 58323    | Bank Transfer    |
# | d526c6ec-7ac4-47e3-83b4-d6d650f0fb74    | f94330d3-7c2f-42ee-af69-cbb31712f740  | 2025-07-07   | Pending   | 6093.84      | 8531 Guzman Roads Suite 460, Beckermouth, KS 65960  | Cash            |
# | 27dd298f-9de0-483d-9af3-1284021d8b43    | 2c51481e-6f1d-47cb-9f38-970004ca390e  | 2025-07-07   | Shipped   | 1915.12      | 71696 Butler Knoll Suite 392, Andrewborough, KY 64325| Bank Transfer    |
#
# If you need more details or have any other questions, feel free to ask!
#
# 📊 Made 1 function call(s)
#
# ============================================================
# 🔍 User Query: Which customer has the highest total spending?
# --------------------------------------------------
# 🔧 Executing: execute_sql_query
# 📝 SQL: SELECT first_name, last_name, total_spent FROM CUSTOMERS ORDER BY total_spent DESC LIMIT 1;
# 💭 Explanation: This query retrieves the customer with the highest total spending by ordering the customers by total_spent in descending order and limiting the result to the top one.
# 🤖 Agent Response:
# The customer with the highest total spending is **Raymond Johnson**, with a total spending of **$4,997.98**.
#
# If you have any more questions or need further information, feel free to ask!
#
# 📊 Made 1 function call(s)

# %% [markdown]
# ## 10. Summary and Next Steps
#
# Congratulations! You've built a complete text-to-SQL RAG system. Here's what we accomplished:
#
# ### ✅ What We Built:
# 1. **Database Setup**: Created a realistic e-commerce database with multiple related tables
# 2. **Basic Text-to-SQL**: Implemented simple natural language to SQL conversion
# 3. **Function Calling**: Used OpenAI's function calling for dynamic query execution
# 4. **Conversational Interface**: Built an agent that maintains context across conversations
# 5. **Safety Measures**: Added query validation and error handling
# 6. **Enhanced Features**: Implemented best practices for production systems
#
# ### 🔧 Key Components:
# - **Data Generation**: Used Faker to create realistic sample data
# - **Database Schema**: Designed normalized tables with proper relationships
# - **LLM Integration**: Leveraged Azure OpenAI for natural language understanding
# - **Error Handling**: Implemented robust error handling and recovery
# - **Security**: Added SQL injection prevention and query validation
#
# ### 🚀 Next Steps:
# 1. **Add more data sources**: Integrate with other databases or APIs
# 2. **Improve error handling**: Add more sophisticated query correction
# 3. **Add caching**: Cache frequent queries for better performance
# 4. **Enhance security**: Implement user authentication and access controls
# 5. **Add visualizations**: Create charts and graphs from query results
# 6. **Deploy as API**: Create a REST API for the text-to-SQL service
#
# ### 📚 Additional Resources:
# - SQLite Documentation: https://www.sqlite.org/docs.html
# - OpenAI Function Calling: https://platform.openai.com/docs/guides/function-calling
# - SQL Best Practices: Focus on performance, security, and maintainability
#
# Try experimenting with different queries and see how the agent handles various scenarios!
